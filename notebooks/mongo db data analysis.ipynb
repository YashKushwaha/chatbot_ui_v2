# %%
from pymongo.collection import Collection

def mongo_value_counts(collection: Collection, field: str, top_n: int = None) -> list:
    """
    Mimics pandas `value_counts()` for a MongoDB collection.

    Parameters:
        collection (Collection): pymongo collection object
        field (str): Field name to count occurrences for
        top_n (int, optional): Number of top results to return (default: all)

    Returns:
        List of tuples: [(value, count), ...]
    """
    pipeline = [
        {
            "$group": {
                "_id": f"${field}",
                "count": {"$sum": 1}
            }
        },
        {
            "$sort": {"count": -1}
        }
    ]
    
    if top_n:
        pipeline.append({"$limit": top_n})
    
    results = collection.aggregate(pipeline)
    
    return [(doc["_id"], doc["count"]) for doc in results]

# %%
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["agent_evaluation_db"]
collection = db["qna_pairs"]

# %%
# Get counts similar to df['col'].value_counts()
counts = mongo_value_counts(collection, "title")

# %%
counts
# Out:
# [('Queen_Victoria', 883),
#  ('New_York_City', 817),
#  ('American_Idol', 790),
#  ('Beyoncé', 753),
#  ('Frédéric_Chopin', 697),
#  ('Buddhism', 610),
#  ('Pharmaceutical_industry', 586),
#  ('New_Haven,_Connecticut', 582),
#  ('Premier_League', 551),
#  ('Hunting', 531),
#  ('Antarctica', 525),
#  ('2008_Sichuan_earthquake', 521),
#  ('Houston', 521),
#  ('Steven_Spielberg', 512),
#  ('PlayStation_3', 508),
#  ('Alfred_North_Whitehead', 502),
#  ('2008_Summer_Olympics_torch_relay', 500),
#  ('Charleston,_South_Carolina', 490),
#  ('Macintosh', 487),
#  ('Muammar_Gaddafi', 485),
#  ('Multiracial_American', 481),
#  ('San_Diego', 475),
#  ('Spectre_(2015_film)', 462),
#  ('Greeks', 458),
#  ('Yale_University', 452),
#  ('Middle_Ages', 452),
#  ('Modern_history', 448),
#  ('Mandolin', 446),
#  ('Freemasonry', 444),
#  ('Windows_8', 442),
#  ('Federal_Bureau_of_Investigation', 441),
#  ('Avicenna', 440),
#  ('Hellenistic_period', 440),
#  ('Affirmative_action_in_the_United_States', 440),
#  ('Slavs', 437),
#  ('Napoleon', 436),
#  ('Miami', 436),
#  ('Bermuda', 434),
#  ('Jehovah%27s_Witnesses', 433),
#  ('Gamal_Abdel_Nasser', 433),
#  ('Elizabeth_II', 431),
#  ('Dwight_D._Eisenhower', 430),
#  ('Red', 429),
#  ('Kanye_West', 428),
#  ('Northwestern_University', 427),
#  ('Portugal', 427),
#  ('Alaska', 426),
#  ('Southampton', 426),
#  ('Dell', 424),
#  ('Capital_punishment_in_the_United_States', 422),
#  ('House_music', 420),
#  ('The_Blitz', 414),
#  ('Military_history_of_the_United_States', 414),
#  ('Dominican_Order', 413),
#  ('Westminster_Abbey', 411),
#  ('Greece', 406),
#  ('Religion_in_ancient_Rome', 405),
#  ('Cork_(city)', 404),
#  ('Gramophone_record', 404),
#  ('Separation_of_church_and_state_in_the_United_States', 402),
#  ('Time', 402),
#  ('Neptune', 399),
#  ('Canadian_Armed_Forces', 396),
#  ('Quran', 396),
#  ('High-definition_television', 394),
#  ('Incandescent_light_bulb', 393),
#  ('Dog', 392),
#  ('Late_Middle_Ages', 392),
#  ('Roman_Republic', 392),
#  ('Karl_Popper', 391),
#  ('Pacific_War', 390),
#  ('Financial_crisis_of_2007%E2%80%9308', 390),
#  ('Mexico_City', 390),
#  ('Paris', 389),
#  ('History_of_India', 389),
#  ('Buckingham_Palace', 388),
#  ('Brigham_Young_University', 386),
#  ('Eritrea', 386),
#  ('Uranium', 385),
#  ('Light-emitting_diode', 385),
#  ('Nintendo_Entertainment_System', 383),
#  ('Edmund_Burke', 383),
#  ('Department_store', 378),
#  ('Anthropology', 378),
#  ('Athanasius_of_Alexandria', 377),
#  ('Emotion', 375),
#  ('Gothic_architecture', 375),
#  ('The_Legend_of_Zelda:_Twilight_Princess', 374),
#  ('Eton_College', 374),
#  ('Dialect', 373),
#  ('Paper', 371),
#  ('Molotov%E2%80%93Ribbentrop_Pact', 371),
#  ('Copyright_infringement', 371),
#  ('Tucson,_Arizona', 370),
#  ('Protestantism', 369),
#  ('Universal_Studios', 368),
#  ('Zhejiang', 367),
#  ('Plymouth', 367),
#  ('Literature', 366),
#  ('Mary_(mother_of_Jesus)', 366),
#  ('Computer_security', 365),
#  ('Capacitor', 364),
#  ('Electric_motor', 363),
#  ('London', 359),
#  ('Namibia', 359),
#  ('British_Isles', 357),
#  ('War_on_Terror', 356),
#  ('Pub', 356),
#  ('Switzerland', 353),
#  ('Post-punk', 352),
#  ('Asphalt', 352),
#  ('Boston', 350),
#  ('Madonna_(entertainer)', 349),
#  ('Korean_War', 348),
#  ('Age_of_Enlightenment', 347),
#  ('Alps', 346),
#  ('Russian_Soviet_Federative_Socialist_Republic', 345),
#  ('Architecture', 344),
#  ('Zinc', 344),
#  ('Insect', 343),
#  ('Washington_University_in_St._Louis', 341),
#  ('Catalan_language', 340),
#  ('Anti-aircraft_warfare', 340),
#  ('Ottoman_Empire', 340),
#  ('University_of_Kansas', 340),
#  ('Myanmar', 339),
#  ('Beer', 339),
#  ('Police', 339),
#  ('Federalism', 338),
#  ('Republic_of_the_Congo', 338),
#  ('Aircraft_carrier', 337),
#  ('Royal_assent', 335),
#  ('Arsenal_F.C.', 334),
#  ('Somerset', 332),
#  ('Sichuan', 332),
#  ('Raleigh,_North_Carolina', 332),
#  ('Law_of_the_United_States', 332),
#  ('Detroit', 330),
#  ('Wood', 328),
#  ('IPod', 327),
#  ('Printed_circuit_board', 325),
#  ('Josip_Broz_Tito', 325),
#  ('Race_(human_categorization)', 325),
#  ('Alexander_Graham_Bell', 325),
#  ('YouTube', 324),
#  ('Qing_dynasty', 324),
#  ('Germans', 324),
#  ('Han_dynasty', 323),
#  ('Comics', 323),
#  ('Tibet', 322),
#  ('Cardinal_(Catholicism)', 322),
#  ('Strasbourg', 321),
#  ('Adolescence', 320),
#  ('United_States_dollar', 319),
#  ('Umayyad_Caliphate', 318),
#  ('Crucifixion_of_Jesus', 318),
#  ('Kievan_Rus%27', 317),
#  ('Presbyterianism', 317),
#  ('Railway_electrification_system', 316),
#  ('FA_Cup', 316),
#  ('Annelid', 314),
#  ('Hunter-gatherer', 313),
#  ('Classical_music', 313),
#  ('Madrasa', 313),
#  ('Saint_Helena', 313),
#  ('Nanjing', 312),
#  ('Mosaic', 311),
#  ('University', 311),
#  ('Poultry', 310),
#  ('Melbourne', 310),
#  ('Florida', 309),
#  ('History_of_science', 309),
#  ('Jews', 308),
#  ('East_India_Company', 307),
#  ('Chihuahua_(state)', 306),
#  ('Somalis', 306),
#  ('BeiDou_Navigation_Satellite_System', 305),
#  ('Richard_Feynman', 304),
#  ('Copper', 304),
#  ('Antenna_(radio)', 302),
#  ('Biodiversity', 302),
#  ('Tajikistan', 302),
#  ('Seven_Years%27_War', 301),
#  ('Cotton', 300),
#  ('Dissolution_of_the_Soviet_Union', 299),
#  ('Tuvalu', 299),
#  ('Antibiotics', 298),
#  ('Estonia', 298),
#  ('Tuberculosis', 298),
#  ('North_Carolina', 297),
#  ('Israel', 297),
#  ('United_States_Army', 296),
#  ('Guam', 295),
#  ('Cubism', 294),
#  ('British_Empire', 293),
#  ('God', 293),
#  ('51st_state', 293),
#  ('Sexual_orientation', 292),
#  ('Memory', 292),
#  ('Norfolk_Island', 292),
#  ('Pain', 292),
#  ('Richmond,_Virginia', 291),
#  ('Sino-Tibetan_relations_during_the_Ming_dynasty', 291),
#  ('Russian_language', 290),
#  ('Infection', 290),
#  ('Unicode', 290),
#  ('MP3', 289),
#  ('Renewable_energy_commercialization', 289),
#  ('Franco-Prussian_War', 287),
#  ('Economy_of_Greece', 287),
#  ('Crimean_War', 287),
#  ('Black_people', 286),
#  ('Textual_criticism', 286),
#  ('Energy', 284),
#  ('Genocide', 284),
#  ('Iran', 282),
#  ('Predation', 282),
#  ('Vacuum', 282),
#  ('Treaty', 281),
#  ('Labour_Party_(UK)', 280),
#  ('Gene', 279),
#  ('Czech_language', 279),
#  ('A_cappella', 278),
#  ('Idealism', 278),
#  ('Translation', 277),
#  ('Szlachta', 276),
#  ('Marshall_Islands', 276),
#  ('Kathmandu', 276),
#  ('Indigenous_peoples_of_the_Americas', 275),
#  ('Nutrition', 275),
#  ('Sanskrit', 275),
#  ('Endangered_Species_Act', 274),
#  ('Sumer', 274),
#  ('Daylight_saving_time', 273),
#  ('Database', 272),
#  ('Pope_Paul_VI', 271),
#  ('Oklahoma', 271),
#  ('States_of_Germany', 270),
#  ('University_of_Notre_Dame', 269),
#  ('Queen_(band)', 269),
#  ('Estonian_language', 269),
#  ('Education', 267),
#  ('The_Bronx', 267),
#  ('Comcast', 266),
#  ('Sahara', 265),
#  ('Planck_constant', 265),
#  ('Thuringia', 264),
#  ('Arena_Football_League', 262),
#  ('Spanish_language_in_the_United_States', 262),
#  ('On_the_Origin_of_Species', 261),
#  ('Party_leaders_of_the_United_States_House_of_Representatives', 261),
#  ('Ann_Arbor,_Michigan', 260),
#  ('Association_football', 260),
#  ('Hyderabad', 260),
#  ('IBM', 260),
#  ('Seattle', 260),
#  ('Aspirated_consonant', 259),
#  ('Carnival', 259),
#  ('Group_(mathematics)', 259),
#  ('Film_speed', 258),
#  ('United_States_presidential_election,_2004', 257),
#  ('Xbox_360', 256),
#  ('Humanism', 256),
#  ('Imperial_College_London', 255),
#  ('Nigeria', 254),
#  ('European_Central_Bank', 253),
#  ('New_Delhi', 253),
#  ('Punjab,_Pakistan', 250),
#  ('John,_King_of_England', 250),
#  ('Valencia', 250),
#  ('Dutch_language', 250),
#  ('Geological_history_of_Earth', 249),
#  ('Hard_rock', 249),
#  ('Solar_energy', 249),
#  ('Glass', 249),
#  ('FC_Barcelona', 249),
#  ('Samoa', 248),
#  ('Cyprus', 247),
#  ('Marvel_Comics', 247),
#  ('Montevideo', 247),
#  ('Egypt', 247),
#  ('National_Archives_and_Records_Administration', 246),
#  ('John_Kerry', 246),
#  ('The_Sun_(United_Kingdom)', 246),
#  ('Royal_Dutch_Shell', 245),
#  ('Bird_migration', 245),
#  ('Political_philosophy', 245),
#  ('Political_party', 245),
#  ('Hindu_philosophy', 245),
#  ('Professional_wrestling', 245),
#  ('Guinea-Bissau', 243),
#  ('Armenians', 243),
#  ('Sony_Music_Entertainment', 242),
#  ('Empiricism', 242),
#  ('Pesticide', 242),
#  ('Muslim_world', 241),
#  ('United_States_Air_Force', 241),
#  ('Armenia', 241),
#  ('Orthodox_Judaism', 240),
#  ('Hokkien', 239),
#  ('Royal_Institute_of_British_Architects', 239),
#  ('Philadelphia', 239),
#  ('Elevator', 239),
#  ('Rajasthan', 239),
#  ('St._John%27s,_Newfoundland_and_Labrador', 238),
#  ('ASCII', 237),
#  ('Child_labour', 236),
#  ('Canadian_football', 236),
#  ('Saint_Barth%C3%A9lemy', 236),
#  ('Ministry_of_Defence_(United_Kingdom)', 236),
#  ('Asthma', 236),
#  ('Nonprofit_organization', 235),
#  ('Samurai', 235),
#  ('USB', 235),
#  ('Communications_in_Somalia', 235),
#  ('Pope_John_XXIII', 234),
#  ('Super_Nintendo_Entertainment_System', 233),
#  ('Botany', 233),
#  ('Tennessee', 232),
#  ('Flowering_plant', 232),
#  ('Swaziland', 231),
#  ('Everton_F.C.', 230),
#  ('Atlantic_City,_New_Jersey', 230),
#  ('Compact_disc', 230),
#  ('Separation_of_powers_under_the_United_States_Constitution', 230),
#  ('Bird', 230),
#  ('Central_African_Republic', 230),
#  ('Near_East', 229),
#  ('Green', 229),
#  ('Alsace', 228),
#  ('Appalachian_Mountains', 228),
#  ('To_Kill_a_Mockingbird', 228),
#  ('Friedrich_Hayek', 227),
#  ('Liberia', 226),
#  ('Himachal_Pradesh', 226),
#  ('Computer', 224),
#  ('Bras%C3%ADlia', 223),
#  ('Brain', 222),
#  ('Arnold_Schwarzenegger', 221),
#  ('Gymnastics', 220),
#  ('Santa_Monica,_California', 220),
#  ('Airport', 220),
#  ('BBC_Television', 219),
#  ('Christian', 218),
#  ('John_von_Neumann', 216),
#  ('Turner_Classic_Movies', 216),
#  ('Transistor', 216),
#  ('Adult_contemporary_music', 216),
#  ('Bacteria', 216),
#  ('Liberal_Party_of_Australia', 216),
#  ('Software_testing', 216),
#  ('Virgil', 215),
#  ('Southeast_Asia', 215),
#  ('Southern_Europe', 214),
#  ('Data_compression', 214),
#  ('List_of_numbered_streets_in_Manhattan', 213),
#  ('Mali', 212),
#  ('East_Prussia', 211),
#  ('Utrecht', 210),
#  ('Gregorian_calendar', 210),
#  ('Chicago_Cubs', 210),
#  ('The_Times', 210),
#  ('Rule_of_law', 209),
#  ('Wayback_Machine', 208),
#  ('Mammal', 208),
#  ('Videoconferencing', 206),
#  ('Neolithic', 205),
#  ('Philosophy_of_space_and_time', 205),
#  ('Heian_period', 205),
#  ('Phonology', 204),
#  ('Heresy', 204),
#  ('Baptists', 203),
#  ('Materialism', 203),
#  ('Clothing', 203),
#  ('Circadian_rhythm', 202),
#  ('Palermo', 201),
#  ('Genome', 201),
#  ('Dutch_Republic', 201),
#  ('Digimon', 200),
#  ('Glacier', 199),
#  ('Supreme_court', 199),
#  ('Comprehensive_school', 198),
#  ('Alloy', 198),
#  ('George_VI', 198),
#  ('Exhibition_game', 198),
#  ('Immaculate_Conception', 197),
#  ('Hanover', 197),
#  ('Prime_minister', 196),
#  ('United_Nations_Population_Fund', 196),
#  ('Canon_law', 195),
#  ('Lancashire', 195),
#  ('Neoclassical_architecture', 193),
#  ('Web_browser', 192),
#  ('Ashkenazi_Jews', 190),
#  ('Geography_of_the_United_States', 190),
#  ('CBC_Television', 190),
#  ('Georgian_architecture', 188),
#  ('Intellectual_property', 188),
#  ('Great_power', 188),
#  ('Old_English', 187),
#  ('Tristan_da_Cunha', 187),
#  ('Culture', 185),
#  ('Bill_%26_Melinda_Gates_Foundation', 185),
#  ('Infrared', 183),
#  ('Serbo-Croatian', 183),
#  ('LaserDisc', 182),
#  ('Diarrhea', 181),
#  ('Political_corruption', 179),
#  ('Oklahoma_City', 179),
#  ('Apollo', 179),
#  ('Symbiosis', 175),
#  ('Hydrogen', 174),
#  ('Space_Race', 173),
#  ('Human_Development_Index', 168),
#  ('Chinese_characters', 168),
#  ('Identity_(social_science)', 168),
#  ('Bern', 164),
#  ('Internet_service_provider', 161),
#  ('Galicia_(Spain)', 159),
#  ('General_Electric', 158),
#  ('Institute_of_technology', 154),
#  ('Mesozoic', 153),
#  ('Montana', 149),
#  ('Warsaw_Pact', 146),
#  ('Matter', 142),
#  ('Lighting', 140),
#  ('Iranian_languages', 140),
#  ('Myocardial_infarction', 126),
#  ('England_national_football_team', 119),
#  ('Communication', 117),
#  ('Federal_Aviation_Administration', 109),
#  ('Great_Plains', 108),
#  ('Digestion', 85),
#  ('Immunology', 85),
#  ('Animal', 79),
#  ('Central_Intelligence_Agency', 65),
#  ('Imamah_(Shia_doctrine)', 64),
#  ('Order_of_the_British_Empire', 63),
#  ('Letter_case', 55),
#  ('Race_and_ethnicity_in_the_United_States_Census', 52),
#  ('Grape', 48),
#  ('Pitch_(music)', 36)]

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'agent_evaluation_db'), 'qna_pairs')

# %%
dir(collection)
# Out:
# ['__annotations__',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
#  '_aggregate_one_result',
#  '_codec_options',
#  '_command',
#  '_conn_for_writes',
#  '_count_cmd',
#  '_create',
#  '_create_helper',
#  '_create_indexes',
#  '_create_search_indexes',
#  '_database',
#  '_delete',
#  '_delete_retryable',
#  '_drop_index',
#  '_find_and_modify',
#  '_full_name',
#  '_insert_one',
#  '_is_protocol',
#  '_list_indexes',
#  '_name',
#  '_read_concern',
#  '_read_preference',
#  '_read_preference_for',
#  '_retryable_non_cursor_read',
#  '_timeout',
#  '_update',
#  '_update_retryable',
#  '_write_concern',
#  '_write_concern_for',
#  '_write_concern_for_cmd',
#  '_write_response_codec_options',
#  'aggregate',
#  'aggregate_raw_batches',
#  'bulk_write',
#  'codec_options',
#  'count_documents',
#  'create_index',
#  'create_indexes',
#  'create_search_index',
#  'create_search_indexes',
#  'database',
#  'delete_many',
#  'delete_one',
#  'distinct',
#  'drop',
#  'drop_index',
#  'drop_indexes',
#  'drop_search_index',
#  'estimated_document_count',
#  'find',
#  'find_one',
#  'find_one_and_delete',
#  'find_one_and_replace',
#  'find_one_and_update',
#  'find_raw_batches',
#  'full_name',
#  'index_information',
#  'insert_many',
#  'insert_one',
#  'list_indexes',
#  'list_search_indexes',
#  'name',
#  'next',
#  'options',
#  'read_concern',
#  'read_preference',
#  'rename',
#  'replace_one',
#  'update_many',
#  'update_one',
#  'update_search_index',
#  'watch',
#  'with_options',
#  'write_concern']

# %%
filter_condition = { "title": "Hunting" }

# %%
cursor = collection.find(filter_condition).limit(5)
for doc in cursor:
    print(doc)
    print(5*'=')
# Out:
# {'_id': ObjectId('68627f6e277fab6848d6ce14'), 'id': '573443cb879d6814001ca423', 'answers': 'Hunting', 'context_hash': 'c0feeb78bdaba73a41231e10931c9d1b', 'question': 'What is the practice of killing or trapping any animal?', 'title': 'Hunting'}
# =====
# {'_id': ObjectId('68627f6e277fab6848d6ce15'), 'id': '573443cb879d6814001ca424', 'answers': 'food', 'context_hash': 'c0feeb78bdaba73a41231e10931c9d1b', 'question': 'Why do humans most commonly hunt wildlife?', 'title': 'Hunting'}
# =====
# {'_id': ObjectId('68627f6e277fab6848d6ce16'), 'id': '573443cb879d6814001ca425', 'answers': 'poaching', 'context_hash': 'c0feeb78bdaba73a41231e10931c9d1b', 'question': 'What is there a distinction between lawful hunting and?', 'title': 'Hunting'}
# =====
# {'_id': ObjectId('68627f6e277fab6848d6ce17'), 'id': '573443cb879d6814001ca426', 'answers': 'illegal killing, trapping or capture of the hunted species', 'context_hash': 'c0feeb78bdaba73a41231e10931c9d1b', 'question': 'What is poaching?', 'title': 'Hunting'}
# =====
# {'_id': ObjectId('68627f6e277fab6848d6ce18'), 'id': '573443cb879d6814001ca427', 'answers': 'prey', 'context_hash': 'c0feeb78bdaba73a41231e10931c9d1b', 'question': 'What is the species which is hunted referred to as?', 'title': 'Hunting'}
# =====
